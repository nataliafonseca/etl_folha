# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nataliafonseca/etl_folha/blob/main/script/notebook.ipynb)

# %%
# Importações
import sqlalchemy
import pandas as pd
import numpy as np

# %%
# Criação da engine do sql alchemy para a tabela
db_connection = sqlalchemy.create_engine(
    'postgresql+pg8000://postgres:123456@localhost:5433/folhadb',
    client_encoding='utf8',
)

# %% [markdown]
# # 1. Extract

# %%
# Extração da tabela cargos para dataframe do pandas
cargos_df = pd.read_sql('SELECT * FROM folha.cargos', db_connection)
cargos_df
# Out:
# Empty DataFrame
# Columns: [cod_cargo, dsc_cargo, cod_carreira]
# Index: []

# %%
# Extração da tabela carreiras para dataframe do pandas
carreiras_df = pd.read_sql('SELECT * FROM folha.carreiras', db_connection)
carreiras_df
# Out:
# Empty DataFrame
# Columns: [cod_carreira, dsc_carreira]
# Index: []

# %%
# Extração da tabela unidades para dataframe do pandas
unidades_df = pd.read_sql('SELECT * FROM folha.unidades', db_connection)
unidades_df
# Out:
#    cod_und               dsc_und    cid_und uf_und
# 0        1     Campus Farolândia    Aracaju     SE
# 1        2         Campus Centro    Aracaju     SE
# 2        3  Clínica Odontológica    Aracaju     SE
# 3        4        Polo Petrolina  Petrolina     PE
# 4        5       Campus Zona Sul     Recife     PE

# %%
# Extração da tabela setores para dataframe do pandas
setores_df = pd.read_sql('SELECT * FROM folha.setores', db_connection)
setores_df
# Out:
#     cod_setor                   dsc_setor  cod_und  cod_colab_chefe
# 0           5                        DAAF        4             6188
# 1           6                        DAAF        2             6141
# 2           7                         DFI        4             6188
# 3           8                         DIM        4             6188
# 4           9                         DNG        4             6188
# 5          10                         DRH        3             5870
# 6          11                         DMK        4             6188
# 7          12                      ASSJUR        3             5870
# 8          13                     COMPESE        3             5870
# 9          14               PÓS-GRADUAÇÃO        4             6188
# 10         15                ALMOXARIFADO        4             6188
# 11         16                 CALL CENTER        4             6188
# 12         17          CENTRAL DE ESTAGIO        4             6188
# 13         18             CENTRO DE SAÚDE        4             6188
# 14         19     GERÊNCIA DE FIDELIZAÇÃO        3             5870
# 15         20                        NEAD        4             6188
# 16         21                       PAACE        4             6188
# 17         22                  PATRIMONIO        4             6188
# 18         23                    REITORIA        4             6188
# 19         24              ADMINISTRATIVO        3             5870
# 20         29    INTELIGENCIA COMPETITIVA        3             5870
# 21         32                        CEAP        4             6188
# 22         33         DEPARTAMENTO MÉDICO        4             6188
# 23         41                     SUPREAL        3             5870
# 24          1                         DTI        3             5870
# 25          2        VICE-PRESIDENCIA ADM        4             6188
# 26          3  VICE-PRESIDENCIA ACADEMICA        4             6188
# 27          4                         DIG        4             6188
# 28         25                     ASSPLAN        3             5870
# 29         27               PÓS-GRADUAÇÃO        2             6141
# 30         34                      ASSCOM        3             5870
# 31         36                     ESTAGIO        4             6188
# 32         28                  BIBLIOTECA        4             6188
# 33         35                         CCS        4             6188
# 34         40                 PRESIDÊNCIA        3             5870
# 35         31                         DFI        2             6141
# 36         37                         DAA        2             6141
# 37         45                    PRONATEC        4             6188
# 38         46               DIRETORIA ADM        2             6141
# 39         43               CONTROLADORIA        3             5870
# 40         44         INTERNACIONALIZAÇÃO        4             6188
# 41         54                       PAACE        2             6141
# 42         49                         ITP        4             6188
# 43         55                       PAACE        1             2952
# 44         52                         DMK        2             6141
# 45         53                         DMK        1             2952
# 46         47                     IDIOMAS        3             5870
# 47         48           MESTRADO/DOUTRADO        4             6188
# 48         50                         DRH        4             6188
# 49         51                         DFI        1             2952
# 50         56               PÓS-GRADUAÇÃO        1             2952
# 51         57                  COMPLIANCE        3             5870
# 52         58                        FIEF        3             5870

# %%
# Extração da tabela evolucoes_funcionais para dataframe do pandas
evolucoes_funcionais_df = pd.read_sql(
    'SELECT * FROM folha.evolucoes_funcionais', db_connection
)
evolucoes_funcionais_df
# Out:
# Empty DataFrame
# Columns: [cod_colab, dat_ini, cod_setor, cod_cargo]
# Index: []

# %%
# Extração da tabela colaboradores para dataframe do pandas
colaboradores_df = pd.read_sql(
    'SELECT * FROM folha.colaboradores', db_connection
)
colaboradores_df
# Out:
#     cod_colab         nom_colab    dat_nasc dat_admissao
# 0        3837       NADJA *****  1959-01-31   1984-01-31
# 1        3471      ALTAIR *****  1952-06-02   1977-06-02
# 2        3544       MARIA *****  1964-07-30   1989-07-30
# 3        3767     CLAUDIO *****  1974-07-31   1999-07-31
# 4        3840      DANIEL *****  1979-06-22   2004-06-22
# 5        3769   ROSIVALDO *****  1956-06-04   1981-06-04
# 6        2741     JURANDI *****  1960-05-21   1985-05-21
# 7        2614       JULIO *****  1957-08-14   1982-08-14
# 8        2633       TANIA *****  1965-07-07   1990-07-07
# 9        2635      TEREZA *****  1966-12-24   1991-12-24
# 10       2658        LUIZ *****  1952-05-13   1977-05-13
# 11       2670      ADELMO *****  1956-10-10   1981-10-10
# 12       2774     CANDIDA *****  1966-12-04   1991-12-04
# 13       2834    PATRICIA *****  1973-02-10   1998-02-10
# 14       2783         ANA *****  1954-03-31   1979-03-31
# 15       2784        JOSE *****  1951-03-11   1976-03-11
# 16       2805       MARIA *****  1959-09-21   1984-09-21
# 17       2827       JORGE *****  1967-04-05   1992-04-05
# 18       2891     ANTONIO *****  1969-01-26   1994-01-26
# 19       2893  CHRISTIANE *****  1969-04-22   1994-04-22
# 20       2899      MARCOS *****  1962-12-10   1987-12-10
# 21       2908     JAILSON *****  1972-06-18   1997-06-18
# 22       2932       MARIA *****  1969-01-25   1994-01-25
# 23       2933   FREDERICO *****  1964-01-14   1989-01-14
# 24       2934        ROSE *****  1964-01-01   1989-01-01
# 25       2935     MARCELO *****  1972-07-28   1997-07-28
# 26       2938      WILSON *****  1965-02-10   1990-02-10
# 27       2939        JOSE *****  1960-12-03   1985-12-03
# 28       2941   ROSANGELA *****  1974-10-13   1999-10-13
# 29       2952     ANTONIO *****  1959-08-19   1984-08-19
# 30       2954      MARCOS *****  1975-05-08   2000-05-08
# 31       2958       MARCO *****  1965-01-31   1990-01-31
# 32       2916       MARIA *****  1965-04-21   1990-04-21
# 33       5867      CARLOS *****  1972-07-26   1997-07-26
# 34       5870       NUBIA *****  1970-04-11   1995-04-11
# 35       6078    EMANUELE *****  1977-12-06   2002-12-06
# 36       6081        JOSE *****  1958-01-19   1983-01-19
# 37       6139    FRANCINE *****  1975-03-25   2000-03-25
# 38       6141         EVA *****  1979-04-12   2004-04-12
# 39       6188       MARIA *****  1976-07-07   2001-07-07

# %%
# Extração da tabela lancamentos para dataframe do pandas
lancamentos_df = pd.read_sql('SELECT * FROM folha.lancamentos', db_connection)
lancamentos_df
# Out:
# Empty DataFrame
# Columns: [ano, mes, tpo_folha, cod_rubrica, cod_colab, dat_lanc, val_lanc]
# Index: []

# %%
# Extração da tabela folhas_pagamentos para dataframe do pandas
folhas_pagamentos_df = pd.read_sql(
    'SELECT * FROM folha.folhas_pagamentos', db_connection
)
folhas_pagamentos_df
# Out:
# Empty DataFrame
# Columns: [ano, mes, tpo_folha, dsc_folha]
# Index: []

# %%
# Extração da tabela rubricas para dataframe do pandas
rubricas_df = pd.read_sql('SELECT * FROM folha.rubricas', db_connection)
rubricas_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dsc_rubrica, tpo_rubrica, cod_grupo]
# Index: []

# %%
# Extração da tabela grupos_rubricas para dataframe do pandas
grupos_rubricas_df = pd.read_sql(
    'SELECT * FROM folha.grupos_rubricas', db_connection
)
grupos_rubricas_df
# Out:
# Empty DataFrame
# Columns: [cod_grupo, dsc_grupo]
# Index: []

# %% [markdown]
# # 2. Transform

# %% [markdown]
# ## dm_cargos

# %%
# Merge de cargos e carreiras
dm_cargos_df = pd.merge(
    left=cargos_df, right=carreiras_df, how='left', on='cod_carreira'
)
dm_cargos_df
# Out:
# Empty DataFrame
# Columns: [cod_cargo, dsc_cargo, cod_carreira, dsc_carreira]
# Index: []

# %%
# Remoção da linha cod_carreira
dm_cargos_df.drop(columns=['cod_carreira'], inplace=True)
dm_cargos_df
# Out:
# Empty DataFrame
# Columns: [cod_cargo, dsc_cargo, dsc_carreira]
# Index: []

# %% [markdown]
# ## dm_setores

# %%
# Merge de setores e unidades
dm_setores_df = pd.merge(
    left=setores_df, right=unidades_df, how='left', on='cod_und'
)
dm_setores_df
# Out:
#     cod_setor                   dsc_setor  cod_und  cod_colab_chefe  \
# 0           5                        DAAF        4             6188
# 1           6                        DAAF        2             6141
# 2           7                         DFI        4             6188
# 3           8                         DIM        4             6188
# 4           9                         DNG        4             6188
# 5          10                         DRH        3             5870
# 6          11                         DMK        4             6188
# 7          12                      ASSJUR        3             5870
# 8          13                     COMPESE        3             5870
# 9          14               PÓS-GRADUAÇÃO        4             6188
# 10         15                ALMOXARIFADO        4             6188
# 11         16                 CALL CENTER        4             6188
# 12         17          CENTRAL DE ESTAGIO        4             6188
# 13         18             CENTRO DE SAÚDE        4             6188
# 14         19     GERÊNCIA DE FIDELIZAÇÃO        3             5870
# 15         20                        NEAD        4             6188
# 16         21                       PAACE        4             6188
# 17         22                  PATRIMONIO        4             6188
# 18         23                    REITORIA        4             6188
# 19         24              ADMINISTRATIVO        3             5870
# 20         29    INTELIGENCIA COMPETITIVA        3             5870
# 21         32                        CEAP        4             6188
# 22         33         DEPARTAMENTO MÉDICO        4             6188
# 23         41                     SUPREAL        3             5870
# 24          1                         DTI        3             5870
# 25          2        VICE-PRESIDENCIA ADM        4             6188
# 26          3  VICE-PRESIDENCIA ACADEMICA        4             6188
# 27          4                         DIG        4             6188
# 28         25                     ASSPLAN        3             5870
# 29         27               PÓS-GRADUAÇÃO        2             6141
# 51  Clínica Odontológica    Aracaju     SE
# 52  Clínica Odontológica    Aracaju     SE

# %%
# Renomeando colunas
dm_setores_df.rename(
    columns={
        'dsc_und': 'dsc_unidade',
        'cid_und': 'cidade_unidade',
        'uf_und': 'uf_unidade',
    },
    inplace=True,
)
dm_setores_df
# Out:
#     cod_setor                   dsc_setor  cod_und  cod_colab_chefe  \
# 0           5                        DAAF        4             6188
# 1           6                        DAAF        2             6141
# 2           7                         DFI        4             6188
# 3           8                         DIM        4             6188
# 4           9                         DNG        4             6188
# 5          10                         DRH        3             5870
# 6          11                         DMK        4             6188
# 7          12                      ASSJUR        3             5870
# 8          13                     COMPESE        3             5870
# 9          14               PÓS-GRADUAÇÃO        4             6188
# 10         15                ALMOXARIFADO        4             6188
# 11         16                 CALL CENTER        4             6188
# 12         17          CENTRAL DE ESTAGIO        4             6188
# 13         18             CENTRO DE SAÚDE        4             6188
# 14         19     GERÊNCIA DE FIDELIZAÇÃO        3             5870
# 15         20                        NEAD        4             6188
# 16         21                       PAACE        4             6188
# 17         22                  PATRIMONIO        4             6188
# 18         23                    REITORIA        4             6188
# 19         24              ADMINISTRATIVO        3             5870
# 20         29    INTELIGENCIA COMPETITIVA        3             5870
# 21         32                        CEAP        4             6188
# 22         33         DEPARTAMENTO MÉDICO        4             6188
# 23         41                     SUPREAL        3             5870
# 24          1                         DTI        3             5870
# 25          2        VICE-PRESIDENCIA ADM        4             6188
# 26          3  VICE-PRESIDENCIA ACADEMICA        4             6188
# 27          4                         DIG        4             6188
# 28         25                     ASSPLAN        3             5870
# 29         27               PÓS-GRADUAÇÃO        2             6141
# 30         34                      ASSCOM        3             5870
# 31         36                     ESTAGIO        4             6188
# 32         28                  BIBLIOTECA        4             6188
# 33         35                         CCS        4             6188
# 34         40                 PRESIDÊNCIA        3             5870
# 35         31                         DFI        2             6141
# 36         37                         DAA        2             6141
# 37         45                    PRONATEC        4             6188
# 38         46               DIRETORIA ADM        2             6141
# 39         43               CONTROLADORIA        3             5870
# 40         44         INTERNACIONALIZAÇÃO        4             6188
# 41         54                       PAACE        2             6141
# 42         49                         ITP        4             6188
# 43         55                       PAACE        1             2952
# 44         52                         DMK        2             6141
# 45         53                         DMK        1             2952
# 46         47                     IDIOMAS        3             5870
# 47         48           MESTRADO/DOUTRADO        4             6188
# 48         50                         DRH        4             6188
# 49         51                         DFI        1             2952
# 50         56               PÓS-GRADUAÇÃO        1             2952
# 51         57                  COMPLIANCE        3             5870
# 52         58                        FIEF        3             5870
#
#              dsc_unidade cidade_unidade uf_unidade
# 0         Polo Petrolina      Petrolina         PE
# 1          Campus Centro        Aracaju         SE
# 2         Polo Petrolina      Petrolina         PE
# 3         Polo Petrolina      Petrolina         PE
# 4         Polo Petrolina      Petrolina         PE
# 5   Clínica Odontológica        Aracaju         SE
# 6         Polo Petrolina      Petrolina         PE
# 7   Clínica Odontológica        Aracaju         SE
# 8   Clínica Odontológica        Aracaju         SE
# 9         Polo Petrolina      Petrolina         PE
# 10        Polo Petrolina      Petrolina         PE
# 11        Polo Petrolina      Petrolina         PE
# 12        Polo Petrolina      Petrolina         PE
# 13        Polo Petrolina      Petrolina         PE
# 26          3  VICE-PRESIDENCIA ACADEMICA        Polo Petrolina
# 27          4                         DIG        Polo Petrolina
# 28         25                     ASSPLAN  Clínica Odontológica
# 29         27               PÓS-GRADUAÇÃO         Campus Centro
# 30         34                      ASSCOM  Clínica Odontológica
# 31         36                     ESTAGIO        Polo Petrolina
# 32         28                  BIBLIOTECA        Polo Petrolina
# 33         35                         CCS        Polo Petrolina
# 34         40                 PRESIDÊNCIA  Clínica Odontológica
# 35         31                         DFI         Campus Centro
# 36         37                         DAA         Campus Centro
# 37         45                    PRONATEC        Polo Petrolina
# 38         46               DIRETORIA ADM         Campus Centro
# 39         43               CONTROLADORIA  Clínica Odontológica
# 40         44         INTERNACIONALIZAÇÃO        Polo Petrolina
# 41         54                       PAACE         Campus Centro
# 42         49                         ITP        Polo Petrolina
# 43         55                       PAACE     Campus Farolândia
# 44         52                         DMK         Campus Centro
# 45         53                         DMK     Campus Farolândia
# 46         47                     IDIOMAS  Clínica Odontológica
# 47         48           MESTRADO/DOUTRADO        Polo Petrolina
# 48         50                         DRH        Polo Petrolina
# 49         51                         DFI     Campus Farolândia
# 50         56               PÓS-GRADUAÇÃO     Campus Farolândia
# 51         57                  COMPLIANCE  Clínica Odontológica
# 52         58                        FIEF  Clínica Odontológica
#
#    cidade_unidade uf_unidade
# 0       Petrolina         PE
# 1         Aracaju         SE
# 2       Petrolina         PE
# 3       Petrolina         PE
# 4       Petrolina         PE
# 5         Aracaju         SE
# 6       Petrolina         PE
# 7         Aracaju         SE
# 8         Aracaju         SE
# 9       Petrolina         PE
# 10      Petrolina         PE
# 11      Petrolina         PE
# 12      Petrolina         PE
# 13      Petrolina         PE
# 14        Aracaju         SE
# 15      Petrolina         PE
# 16      Petrolina         PE
# 17      Petrolina         PE
# 18      Petrolina         PE
# 19        Aracaju         SE
# 20        Aracaju         SE
# 21      Petrolina         PE
# 22      Petrolina         PE
# 23        Aracaju         SE
# 24        Aracaju         SE
# 25      Petrolina         PE
# 26      Petrolina         PE
# 27      Petrolina         PE
# 28        Aracaju         SE
# 29        Aracaju         SE
# 30        Aracaju         SE
# 31      Petrolina         PE
# 32      Petrolina         PE
# 33      Petrolina         PE
# 34        Aracaju         SE
# 35        Aracaju         SE
# 36        Aracaju         SE
# 37      Petrolina         PE
# 38        Aracaju         SE
# 39        Aracaju         SE
# 40      Petrolina         PE
# 41        Aracaju         SE
# 42      Petrolina         PE
# 43        Aracaju         SE
# 44        Aracaju         SE
# 45        Aracaju         SE
# 46        Aracaju         SE
# 47      Petrolina         PE
# 48      Petrolina         PE
# 49        Aracaju         SE
# 50        Aracaju         SE
# 51        Aracaju         SE
# 52        Aracaju         SE

# %% [markdown]
# ## dm_rubricas

# %%
# Merge de rubricas e grupos_rubricas
dm_rubricas_df = pd.merge(
    left=rubricas_df, right=grupos_rubricas_df, how='left', on='cod_grupo'
)
dm_rubricas_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dsc_rubrica, tpo_rubrica, cod_grupo, dsc_grupo]
# Index: []

# %%
# Remoção da linha cod_grupo
dm_rubricas_df.drop(columns=['cod_grupo'], inplace=True)
dm_rubricas_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dsc_rubrica, tpo_rubrica, dsc_grupo]
# Index: []

# %% [markdown]
# ## dm_faixas_etarias

# %%
# Criação do dataframe dm_faixas_etárias
dm_faixas_etarias_df = pd.DataFrame(
    {
        'cod_faixa': [1, 2, 3, 4],
        'dsc_faixa': [
            'até 21 anos',
            'de 21 a 30 anos',
            'de 31 a 45 anos',
            'acima de 45 anos',
        ],
        'idade_inicial': [0, 22, 31, 45],
        'idade_final': [21, 30, 45, 100],
    }
)
dm_faixas_etarias_df
# Out:
#    cod_faixa         dsc_faixa  idade_inicial  idade_final
# 0          1       até 21 anos              0           21
# 1          2   de 21 a 30 anos             22           30
# 2          3   de 31 a 45 anos             31           45
# 3          4  acima de 45 anos             45          100

# %% [markdown]
# ## dm_tempos_servicos

# %%
# Criação da do dataframe dm_tempo_servicos
dm_tempos_servicos_df = pd.DataFrame(
    {
        'cod_tempo_serv': [1, 2, 3, 4, 5],
        'dsc_tempo_serv': [
            'até 1 ano',
            'de 1 a 10 anos',
            'de 11 a 20 anos',
            'de 21 a 30 anos',
            'acima de 31 anos',
        ],
        'ano_inicial': [0, 1, 11, 21, 31],
        'ano_final': [0, 10, 20, 30, 100],
    }
)
dm_tempos_servicos_df
# Out:
#    cod_tempo_serv    dsc_tempo_serv  ano_inicial  ano_final
# 0               1         até 1 ano            0          0
# 1               2    de 1 a 10 anos            1         10
# 2               3   de 11 a 20 anos           11         20
# 3               4   de 21 a 30 anos           21         30
# 4               5  acima de 31 anos           31        100

# %% [markdown]
# ## dm_tempos_folhas

# %%
# Criação da do dataframe dm_tempos_folhas a partir de folhas_pagamentos, removendo as linha tpo_folha e dsc_folha
dm_tempos_folhas_df = folhas_pagamentos_df.drop(columns=['tpo_folha', 'dsc_folha'], inplace=False)
dm_tempos_folhas_df
# Out:
# Empty DataFrame
# Columns: [ano, mes]
# Index: []

# %%
# Criação da coluna id_ano_mes a partir de ano e mês
dm_tempos_folhas_df['id_ano_mes'] = (dm_tempos_folhas_df['ano'].astype(str) + dm_tempos_folhas_df['mes'].astype(str)).astype(int)
dm_tempos_folhas_df
# Out:
# Empty DataFrame
# Columns: [ano, mes, id_ano_mes]
# Index: []

# %% [markdown]
# ## ft_lancamentos

# %%
# Merge das tabelas lancamentos, folhas_pagamento, colaboradores e evoluções funcionais
ft_lancamentos_df = pd.merge(left=lancamentos_df, right=folhas_pagamentos_df, how='left', on=['ano', 'mes', 'tpo_folha'])
ft_lancamentos_df = pd.merge(left=ft_lancamentos_df, right=colaboradores_df, how='left', on='cod_colab')
ft_lancamentos_df = pd.merge(left=ft_lancamentos_df, right=evolucoes_funcionais_df, how='right', on='cod_colab')
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dat_lanc, val_lanc, ano, mes, tpo_folha, dsc_folha, nom_colab, dat_nasc, dat_admissao, cod_colab, dat_ini, cod_setor, cod_cargo]
# Index: []

# %%
# Criação da coluna id_ano_mes a partir de ano e mês
ft_lancamentos_df['id_ano_mes'] = (ft_lancamentos_df['ano'].astype(str) + ft_lancamentos_df['mes'].astype(str)).astype(int)
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dat_lanc, val_lanc, ano, mes, tpo_folha, dsc_folha, nom_colab, dat_nasc, dat_admissao, cod_colab, dat_ini, cod_setor, cod_cargo, id_ano_mes]
# Index: []

# %%
# Coluna cod_faixa
# Criação da coluna idade_colab a partir da data de nascimento do colaborador e data do lançamento
ft_lancamentos_df['idade_colab'] = (pd.to_datetime(ft_lancamentos_df['dat_lanc']) - pd.to_datetime(ft_lancamentos_df['dat_nasc'])) // np.timedelta64(1, 'Y')

# Função para obter o cod_faixa a partir da idade_colab
def get_cod_faixa(idade_colab):
    list_cod_faixa = []
    for idade in idade_colab:
        if idade < 21: 
            list_cod_faixa.append(1)
        elif idade <= 30:
            list_cod_faixa.append(2)
        elif idade <= 45:
            list_cod_faixa.append(3)
        else:
            list_cod_faixa.append(4)
    return list_cod_faixa

ft_lancamentos_df['cod_faixa'] = get_cod_faixa(ft_lancamentos_df['idade_colab'])
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dat_lanc, val_lanc, ano, mes, tpo_folha, dsc_folha, nom_colab, dat_nasc, dat_admissao, cod_colab, dat_ini, cod_setor, cod_cargo, id_ano_mes, idade_colab, cod_faixa]
# Index: []

# %%
# Coluna cod_temp_serv
# Criação da coluna tempo_serv a partir da data de admissão do colaborador e data do lançamento
ft_lancamentos_df['tempo_serv'] = (pd.to_datetime(ft_lancamentos_df['dat_lanc']) - pd.to_datetime(ft_lancamentos_df['dat_admissao'])) // np.timedelta64(1, 'Y')

# Função para obter o cod_temp_serv a partir do tempo_serv
def get_cod_tempo_serv(tempo_serv):
    list_tempo_serv = []
    for idade in tempo_serv:
        if idade  == 0: 
            list_tempo_serv.append(1)
        elif idade <= 10:
            list_tempo_serv.append(2)
        elif idade <= 20:
            list_tempo_serv.append(3)
        elif idade <= 30:
            list_tempo_serv.append(4)
        else:
            list_tempo_serv.append(5)
    return list_tempo_serv

ft_lancamentos_df['cod_tempo_serv'] = get_cod_tempo_serv(ft_lancamentos_df['tempo_serv'])
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, dat_lanc, val_lanc, ano, mes, tpo_folha, dsc_folha, nom_colab, dat_nasc, dat_admissao, cod_colab, dat_ini, cod_setor, cod_cargo, id_ano_mes, idade_colab, cod_faixa, tempo_serv, cod_tempo_serv]
# Index: []

# %%
# Remoção de colunas desnecessárias
ft_lancamentos_df.drop(columns=['dat_lanc', 'ano', 'mes', 'tpo_folha', 'dsc_folha', 'nom_colab', 'dat_nasc', 'dat_admissao', 'cod_colab', 'dat_ini', 'tempo_serv'], inplace=True)
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, val_lanc, cod_setor, cod_cargo, id_ano_mes, idade_colab, cod_faixa, cod_tempo_serv]
# Index: []

# %%
# Renomeando val_lanc para total_lanc
ft_lancamentos_df.rename(columns={'val_lanc': 'total_lanc'}, inplace=True)
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, total_lanc, cod_setor, cod_cargo, id_ano_mes, idade_colab, cod_faixa, cod_tempo_serv]
# Index: []

# %%
# Reordenação das colunas
ft_lancamentos_df = ft_lancamentos_df[['cod_rubrica', 'cod_setor', 'cod_cargo', 'cod_faixa', 'cod_tempo_serv', 'id_ano_mes', 'total_lanc']]
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, cod_setor, cod_cargo, cod_faixa, cod_tempo_serv, id_ano_mes, total_lanc]
# Index: []

# %%
# Criação das colunas valor_bruto, valor_desconto e valor_liquido  #FIXME
ft_lancamentos_df['valor_bruto'] = ft_lancamentos_df['total_lanc']
ft_lancamentos_df['valor_desconto'] = ft_lancamentos_df['total_lanc'] * 0.1
ft_lancamentos_df['valor_liquido'] = ft_lancamentos_df['valor_bruto'] - ft_lancamentos_df['valor_desconto']
ft_lancamentos_df
# Out:
# Empty DataFrame
# Columns: [cod_rubrica, cod_setor, cod_cargo, cod_faixa, cod_tempo_serv, id_ano_mes, total_lanc, valor_bruto, valor_desconto, valor_liquido]
# Index: []

# %% [markdown]
# # 3. Load

# %%
# Função para calculo do chunksize
def get_chunksize(table_columns):
    cs = 2097 // len(table_columns)
    cs = (1000 if cs > 1000 else cs)
    return cs

# %%
# Exportação do dataframe dm_cargos_df do pandas para a tabela dm_cargos
dm_cargos_df.to_sql(
    name='dm_cargos',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(dm_cargos_df.columns),
)
# Out:
# 0

# %%
# Exportação do dataframe dm_setores_df do pandas para a tabela dm_setores
dm_setores_df.to_sql(
    name='dm_setores',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(dm_setores_df.columns),
)
# Out:
# 53

# %%
# Exportação do dataframe dm_rubricas_df do pandas para a tabela dm_rubricas
dm_rubricas_df.to_sql(
    name='dm_rubricas',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(dm_rubricas_df.columns),
)
# Out:
# 0

# %%
# Exportação do dataframe dm_faixas_etarias_df do pandas para a tabela dm_faixas_etarias
dm_faixas_etarias_df.to_sql(
    name='dm_faixas_etarias',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(dm_faixas_etarias_df.columns),
)
# Out:
# 4

# %%
# Exportação do dataframe dm_tempos_servicos_df do pandas para a tabela dm_tempos_servicos
dm_tempos_servicos_df.to_sql(
    name='dm_tempos_servicos',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(dm_tempos_servicos_df.columns),
)
# Out:
# 5

# %%
# Exportação do dataframe dm_tempos_folhas_df do pandas para a tabela dm_tempos_folhas
dm_tempos_folhas_df.to_sql(
    name='dm_tempos_folhas',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(dm_tempos_folhas_df.columns),
)
# Out:
# 0

# %%
# Exportação do dataframe ft_lancamentos_df do pandas para a tabela ft_lancamentos
ft_lancamentos_df.to_sql(
    name='ft_lancamentos',
    schema='folhadw',
    con=db_connection,
    index=False,
    if_exists='append',
    chunksize=get_chunksize(ft_lancamentos_df.columns),
)
# Out:
# 0
